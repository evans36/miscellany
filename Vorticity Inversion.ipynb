# %% [markdown]
# <h2>Vorticity Inversion</h2>
#
# This Notebook demonstrates how to 'invert' a relative vorticity field to obtain the horizontal winds uniquely associated with that field (i.e., the non-divergent wind) over a limited-area domain.
#
# This example uses a real-time GFS analysis to invert the analyzed 850-hPa relative vorticity associated with Hurricane Dora (2023) in the Central Pacific.
#
# <hr>
#
# We start by loading the required modules:
# <ul>
#     <li><b>boto3</b> to access GFS data hosted on Amazon Web Services' S3 NOAA GFS bucket. We also need to import a couple of modules from <b>botocore</b> to access the GFS bucket via boto3 without AWS credentials.</li>
#     <li><b>xarray</b> to open and parse the data. Note that an appropriate GRIB decoder such as cfgrib must be installed in order for xarray to be able to read GRIB-formatted data.</li>
#     <li><b>metpy</b> to compute the relative vorticity.</li>
#     <li><b>matplotlib</b> and <b>cartopy</b> to create maps from the data. We also import <b>numpy</b> to help with latitude/longitude lines for the maps.</li>
# </ul>

# %%
import xarray as xr
import windspharm
import numpy as np
import boto3
import metpy.calc as mpcalc
from botocore import UNSIGNED
from botocore.config import Config
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import matplotlib.ticker as mticker
import cartopy.crs as crs
from cartopy.feature import NaturalEarthFeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %% [markdown]
# We'll now download the desired GFS analysis - here being the 1200 UTC 9 August 2023 analysis. We use the 0.5° analysis to save computational time. This is just shy of 150 MB, so it may take a minute to download on slower connections.

# %%
client = boto3.client('s3', config=Config(signature_version=UNSIGNED))
client.download_file('noaa-gfs-bdp-pds', 'gfs.20230809/12/atmos/gfs.t12z.pgrb2.0p50.f000', 'gfs.t12z.pgrb2.0p50.f000')

# %% [markdown]
# Let's open the data into two arrays, one for the 850 hPa <i>u</i> wind component and one for the 850 hPa <i>v</i> wind component:

# %%
u850 = xr.open_dataset('gfs.t12z.pgrb2.0p50.f000', engine='cfgrib', filter_by_keys={'typeOfLevel': 'isobaricInhPa', 'shortName': 'u', 'level': 850})
u = u850.u
v850 = xr.open_dataset('gfs.t12z.pgrb2.0p50.f000', engine='cfgrib', filter_by_keys={'typeOfLevel': 'isobaricInhPa', 'shortName': 'v', 'level': 850})
v = v850.v

# %% [markdown]
# Now that we've opened our dataset, let's create a plot of 850 hPa relative vorticity over a limited region corresponding to Hurricane Dora.

# %%
# Create a figure instance.
fig = plt.figure(figsize=(12,9), dpi=300.)

# Create a set of axes for the figure and set
# its map projection to that of the input data.
ax = plt.axes(projection=crs.PlateCarree())

# Add country borders and coastlines.
countries = NaturalEarthFeature(category="cultural", scale="50m",
                                      facecolor="none",
                                      name="admin_0_countries")
ax.add_feature(countries, linewidth=.5, edgecolor="black")
ax.coastlines('50m', linewidth=0.8)

# Compute the 850 hPa relative vorticity.
vort850 = mpcalc.vorticity(u, v)

# Plot the 850 hPa relative vorticity using xarray's plot functionality.
plot = vort850.plot(levels=np.arange(-1.e-4, 1.e-4, 0.2e-5), cmap=get_cmap('PRGn'), transform=crs.PlateCarree(), cbar_kwargs={'label':'relative vorticity (x$10^{-5} s^{-1}$)', 'shrink': 0.98})

# Set the map's extent to cover just Hurricane Dora.
ax.set_extent([-180.,-150.,0.,20.],crs=crs.PlateCarree())

# Add latitude/longitude gridlines.
gridlines = ax.gridlines(color="grey", linestyle="dotted", draw_labels=True)
gridlines.xlabels_top = False
gridlines.ylabels_right = False
gridlines.xlocator = mticker.FixedLocator(np.arange(-180.,149.,5.))
gridlines.ylocator = mticker.FixedLocator(np.arange(0.,21.,5.))
gridlines.xlabel_style = {'size':12, 'color':'black'}
gridlines.ylabel_style = {'size':12, 'color':'black'}
gridlines.xformatter = LONGITUDE_FORMATTER
gridlines.yformatter = LATITUDE_FORMATTER

# Add a plot title, then show the image.
plt.title("GFS 0-h 850 hPa relative vorticity (x$10^{-5} s^{-1}$) at 1200 UTC 9 August 2023")
plt.show()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/metpy/xarray.py:354: UserWarning: More than one time coordinate present for variable "u".
#   + varname + '.')
# /opt/tljh/user/lib/python3.7/site-packages/pint/quantity.py:1309: RuntimeWarning: invalid value encountered in true_divide
#   magnitude = magnitude_op(new_self._magnitude, other._magnitude)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %% [markdown]
# Hurricane Dora was located at 11.4°N, 163.1°W at 1200 UTC 9 August 2023. The plot above shows that Dora is a fairly small hurricane, with cyclonic relative vorticity that can reliably be ascribed to Dora located between 5-13.5°N, 169-158°W. For the vorticity inversion, we want to keep the relative vorticity within this box but make it zero everywhere else.

# %%
# Note the need to use 0->360° rather than -180->180° longitude in defining the mask.
mask = ((vort850.latitude <= 13.5) & (vort850.latitude >= 5.0) & (vort850.longitude <= 202.) & (vort850.longitude >= 191.))
vortmask = vort850.where(mask)
vortmask = vortmask.fillna(0.0)

# %% [markdown]
# We now want to compute the non-divergent (i.e., that associated with rotation) component of the wind. The relative vorticity is equal to the Laplacian of the streamfunction on a horizontal surface. Solving this Poisson equation and using the relationship between the streamfunction and horizontal wind components, we can obtain expressions for the u- and v-components of the non-divergent wind in terms of the relative vorticity. The equations below follow Oertel and Schemm (2021, QJRMS), specifically their Eqns. (8) and (9).
#
# We start by computing the horizontal distance between grid points in the data.

# %%
dx, dy = mpcalc.lat_lon_grid_deltas(vortmask.longitude, vortmask.latitude)
dx = np.abs(dx)
dy = np.abs(dy)

# %% [markdown]
# Next, we create variables to store the spatially varying non-divergent wind (upsi, vpsi).

# %%
upsi = xr.zeros_like(vortmask)
vpsi = xr.zeros_like(vortmask)

# %% [markdown]
# We want to compute the contribution of the vorticity within our bounding box to the non-divergent wind across a larger subset of the GFS grid. To do so, we need to find the indices of our bounding box (corresponding to 5-13.5°N, 158-169°W, as above) and of the desired larger subset of the GFS grid. We want this to be a bit larger than the map extent above so that we can fully encompass Hawaii, so let's use 0-30°N, 140-180°W for this larger subset.

# %%
x_ll = list(vortmask.longitude.values).index(191.0)
x_ur = list(vortmask.longitude.values).index(202.0)
y_ll = list(vortmask.latitude.values).index(5.0)
y_ur = list(vortmask.latitude.values).index(13.5)

x_ll_subset = list(vortmask.longitude.values).index(180.0)
x_ur_subset = list(vortmask.longitude.values).index(220.0)
y_ll_subset = list(vortmask.latitude.values).index(0.0)
y_ur_subset = list(vortmask.latitude.values).index(30.0)

# %% [markdown]
# Now that we have our bounding box, we can iteratively compute the non-divergent component of the wind. Note that since y = 1 is the top latitude (90°N) rather than bottom latitude (90°S), the loop in latitude is top-down.

# %%
# Iterate over each model grid point (larger area).
# i and j refer to x and y in the Oertel and Schemm (2021) equations.
for i in range(x_ll_subset, x_ur_subset):
    for j in range(y_ur_subset, y_ll_subset): 

# Computing the contribution to each other grid point (masked area).
# x1 and y1 refer to x' and y' in the Oertel and Schemm (2021) equations.
        for x1 in range(x_ll, x_ur):
            for y1 in range(y_ur, y_ll):
                outer_point = [i,j]
                inner_point = [x1,y1]
                
                if inner_point != outer_point:
                    
                # Compute x-x', y-y', and r^2...
                    xdiff = (i-x1)*dx[y1,x1].magnitude
                    ydiff = (j-y1)*dy[y1,x1].magnitude
                    rsq = (xdiff*xdiff) + (ydiff*ydiff)
                
                # Compute the non-divergent flow contribution.
                    upsi[j,i] += vortmask[y1,x1].values * -1.0 * (ydiff / rsq) * dx[y1,x1].magnitude * dy[y1,x1].magnitude
                    vpsi[j,i] += vortmask[y1,x1].values * (xdiff / rsq) * dx[y1,x1].magnitude * dy[y1,x1].magnitude

        # Once all points have been iterated over, scale by 1/2pi.
        upsi[j,i] = (1/(2*np.pi)) * upsi[j,i]
        vpsi[j,i] = (1/(2*np.pi)) * vpsi[j,i]
        print('finished with ',outer_point)
# Out:
# finished with  [360, 120]
# finished with  [360, 121]
# finished with  [360, 122]
# finished with  [360, 123]
# finished with  [360, 124]
# finished with  [360, 125]
# finished with  [360, 126]
# finished with  [360, 127]
# finished with  [360, 128]
# finished with  [360, 129]
# finished with  [360, 130]
# finished with  [360, 131]
# finished with  [360, 132]
# finished with  [360, 133]
# finished with  [360, 134]
# finished with  [360, 135]
# finished with  [360, 136]
# finished with  [360, 137]
# finished with  [360, 138]
# finished with  [360, 139]
# finished with  [360, 140]
# finished with  [360, 141]
# finished with  [360, 142]
# finished with  [360, 143]
# finished with  [360, 144]
# finished with  [360, 145]
# finished with  [360, 146]
# finished with  [360, 147]
# finished with  [360, 148]
# finished with  [360, 149]
# finished with  [360, 150]
# finished with  [360, 151]
# finished with  [360, 152]
# finished with  [360, 153]
# finished with  [360, 154]
# finished with  [360, 155]
# finished with  [360, 156]
# finished with  [360, 157]
# finished with  [360, 158]
# finished with  [360, 159]
# finished with  [360, 160]
# finished with  [360, 161]
# finished with  [360, 162]
# finished with  [360, 163]
# finished with  [360, 164]
# finished with  [360, 165]
# finished with  [360, 166]
# finished with  [360, 167]
# finished with  [360, 168]
# finished with  [360, 169]
# finished with  [360, 170]
# finished with  [360, 171]
# finished with  [360, 172]
# finished with  [360, 173]
# finished with  [360, 174]
# finished with  [360, 175]
# finished with  [360, 176]
# finished with  [360, 177]
# finished with  [360, 178]
# finished with  [360, 179]
# finished with  [361, 120]
# finished with  [361, 121]
# finished with  [361, 122]
# finished with  [361, 123]
# finished with  [361, 124]
# finished with  [361, 125]
# finished with  [361, 126]
# finished with  [361, 127]
# finished with  [361, 128]
# finished with  [361, 129]
# finished with  [361, 130]
# finished with  [361, 131]
# finished with  [361, 132]
# finished with  [361, 133]
# finished with  [361, 134]
# finished with  [361, 135]
# finished with  [361, 136]
# finished with  [361, 137]
# finished with  [361, 138]
# finished with  [361, 139]
# finished with  [361, 140]
# finished with  [361, 141]
# finished with  [361, 142]
# finished with  [361, 143]
# finished with  [361, 144]
# finished with  [361, 145]
# finished with  [361, 146]
# finished with  [361, 147]
# finished with  [361, 148]
# finished with  [361, 149]
# finished with  [361, 150]
# finished with  [361, 151]
# finished with  [361, 152]
# finished with  [361, 153]
# finished with  [361, 154]
# finished with  [361, 155]
# finished with  [361, 156]
# finished with  [361, 157]
# finished with  [361, 158]
# finished with  [361, 159]
# finished with  [361, 160]
# finished with  [361, 161]
# finished with  [361, 162]
# finished with  [361, 163]
# finished with  [361, 164]
# finished with  [361, 165]
# finished with  [361, 166]
# finished with  [361, 167]
# finished with  [361, 168]
# finished with  [361, 169]
# finished with  [361, 170]
# finished with  [361, 171]
# finished with  [361, 172]
# finished with  [361, 173]
# finished with  [361, 174]
# finished with  [361, 175]
# finished with  [361, 176]
# finished with  [361, 177]
# finished with  [361, 178]
# finished with  [361, 179]
# finished with  [362, 120]
# finished with  [362, 121]
# finished with  [362, 122]
# finished with  [362, 123]
# finished with  [362, 124]
# finished with  [362, 125]
# finished with  [362, 126]
# finished with  [362, 127]
# finished with  [362, 128]
# finished with  [362, 129]
# finished with  [362, 130]
# finished with  [362, 131]
# finished with  [362, 132]
# finished with  [362, 133]
# finished with  [362, 134]
# finished with  [362, 135]
# finished with  [362, 136]
# finished with  [362, 137]
# finished with  [362, 138]
# finished with  [362, 139]
# finished with  [362, 140]
# finished with  [362, 141]
# finished with  [362, 142]
# finished with  [362, 143]
# finished with  [362, 144]
# finished with  [362, 145]
# finished with  [362, 146]
# finished with  [362, 147]
# finished with  [362, 148]
# finished with  [362, 149]
# finished with  [362, 150]
# finished with  [362, 151]
# finished with  [362, 152]
# finished with  [362, 153]
# finished with  [362, 154]
# finished with  [362, 155]
# finished with  [362, 156]
# finished with  [362, 157]
# finished with  [362, 158]
# finished with  [362, 159]
# finished with  [362, 160]
# finished with  [362, 161]
# finished with  [362, 162]
# finished with  [362, 163]
# finished with  [362, 164]
# finished with  [362, 165]
# finished with  [362, 166]
# finished with  [362, 167]
# finished with  [362, 168]
# finished with  [362, 169]
# finished with  [362, 170]
# finished with  [362, 171]
# finished with  [362, 172]
# finished with  [362, 173]
# finished with  [362, 174]
# finished with  [362, 175]
# finished with  [362, 176]
# finished with  [362, 177]
# finished with  [362, 178]
# finished with  [362, 179]
# finished with  [363, 120]
# finished with  [363, 121]
# finished with  [363, 122]
# finished with  [363, 123]
# finished with  [363, 124]
# finished with  [363, 125]
# finished with  [363, 126]
# finished with  [363, 127]
# finished with  [363, 128]
# finished with  [363, 129]
# finished with  [363, 130]
# finished with  [363, 131]
# finished with  [363, 132]
# finished with  [363, 133]
# finished with  [363, 134]
# finished with  [363, 135]
# finished with  [363, 136]
# finished with  [363, 137]
# finished with  [363, 138]
# finished with  [363, 139]
# finished with  [363, 140]
# finished with  [363, 141]
# finished with  [363, 142]
# finished with  [363, 143]
# finished with  [363, 144]
# finished with  [363, 145]
# finished with  [363, 146]
# finished with  [363, 147]
# finished with  [363, 148]
# finished with  [363, 149]
# finished with  [363, 150]
# finished with  [363, 151]
# finished with  [363, 152]
# finished with  [363, 153]
# finished with  [363, 154]
# finished with  [363, 155]
# finished with  [363, 156]
# finished with  [363, 157]
# finished with  [363, 158]
# finished with  [363, 159]
# finished with  [363, 160]
# finished with  [363, 161]
# finished with  [363, 162]
# finished with  [363, 163]
# finished with  [363, 164]
# finished with  [363, 165]
# finished with  [363, 166]
# finished with  [363, 167]
# finished with  [363, 168]
# finished with  [363, 169]
# finished with  [363, 170]
# finished with  [363, 171]
# finished with  [363, 172]
# finished with  [363, 173]
# finished with  [363, 174]
# finished with  [363, 175]
# finished with  [363, 176]
# finished with  [363, 177]
# finished with  [363, 178]
# finished with  [363, 179]
# finished with  [364, 120]
# finished with  [364, 121]
# finished with  [364, 122]
# finished with  [364, 123]
# finished with  [364, 124]
# finished with  [364, 125]
# finished with  [364, 126]
# finished with  [364, 127]
# finished with  [364, 128]
# finished with  [364, 129]
# finished with  [364, 130]
# finished with  [364, 131]
# finished with  [364, 132]
# finished with  [364, 133]
# finished with  [364, 134]
# finished with  [364, 135]
# finished with  [364, 136]
# finished with  [364, 137]
# finished with  [364, 138]
# finished with  [364, 139]
# finished with  [364, 140]
# finished with  [364, 141]
# finished with  [364, 142]
# finished with  [364, 143]
# finished with  [364, 144]
# finished with  [364, 145]
# finished with  [364, 146]
# finished with  [364, 147]
# finished with  [364, 148]
# finished with  [364, 149]
# finished with  [364, 150]
# finished with  [364, 151]
# finished with  [364, 152]
# finished with  [364, 153]
# finished with  [364, 154]
# finished with  [364, 155]
# finished with  [364, 156]
# finished with  [364, 157]
# finished with  [364, 158]
# finished with  [364, 159]
# finished with  [364, 160]
# finished with  [364, 161]
# finished with  [364, 162]
# finished with  [364, 163]
# finished with  [364, 164]
# finished with  [364, 165]
# finished with  [364, 166]
# finished with  [364, 167]
# finished with  [364, 168]
# finished with  [364, 169]
# finished with  [364, 170]
# finished with  [364, 171]
# finished with  [364, 172]
# finished with  [364, 173]
# finished with  [364, 174]
# finished with  [364, 175]
# finished with  [364, 176]
# finished with  [364, 177]
# finished with  [364, 178]
# finished with  [364, 179]
# finished with  [365, 120]
# finished with  [365, 121]
# finished with  [365, 122]
# finished with  [365, 123]
# finished with  [365, 124]
# finished with  [365, 125]
# finished with  [365, 126]
# finished with  [365, 127]
# finished with  [365, 128]
# finished with  [365, 129]
# finished with  [365, 130]
# finished with  [365, 131]
# finished with  [365, 132]
# finished with  [365, 133]
# finished with  [365, 134]
# finished with  [365, 135]
# finished with  [365, 136]
# finished with  [365, 137]
# finished with  [365, 138]
# finished with  [365, 139]
# finished with  [365, 140]
# finished with  [365, 141]
# finished with  [365, 142]
# finished with  [365, 143]
# finished with  [365, 144]
# finished with  [365, 145]
# finished with  [365, 146]
# finished with  [365, 147]
# finished with  [365, 148]
# finished with  [365, 149]
# finished with  [365, 150]
# finished with  [365, 151]
# finished with  [365, 152]
# finished with  [365, 153]
# finished with  [365, 154]
# finished with  [365, 155]
# finished with  [365, 156]
# finished with  [365, 157]
# finished with  [365, 158]
# finished with  [365, 159]
# finished with  [365, 160]
# finished with  [365, 161]
# finished with  [365, 162]
# finished with  [365, 163]
# finished with  [365, 164]
# finished with  [365, 165]
# finished with  [365, 166]
# finished with  [365, 167]
# finished with  [365, 168]
# finished with  [365, 169]
# finished with  [365, 170]
# finished with  [365, 171]
# finished with  [365, 172]
# finished with  [365, 173]
# finished with  [365, 174]
# finished with  [365, 175]
# finished with  [365, 176]
# finished with  [365, 177]
# finished with  [365, 178]
# finished with  [365, 179]
# finished with  [366, 120]
# finished with  [366, 121]
# finished with  [366, 122]
# finished with  [366, 123]
# finished with  [366, 124]
# finished with  [366, 125]
# finished with  [366, 126]
# finished with  [366, 127]
# finished with  [366, 128]
# finished with  [366, 129]
# finished with  [366, 130]
# finished with  [366, 131]
# finished with  [366, 132]
# finished with  [366, 133]
# finished with  [366, 134]
# finished with  [366, 135]
# finished with  [366, 136]
# finished with  [366, 137]
# finished with  [366, 138]
# finished with  [366, 139]
# finished with  [366, 140]
# finished with  [366, 141]
# finished with  [366, 142]
# finished with  [366, 143]
# finished with  [366, 144]
# finished with  [366, 145]
# finished with  [366, 146]
# finished with  [366, 147]
# finished with  [366, 148]
# finished with  [366, 149]
# finished with  [366, 150]
# finished with  [366, 151]
# finished with  [366, 152]
# finished with  [366, 153]
# finished with  [366, 154]
# finished with  [366, 155]
# finished with  [366, 156]
# finished with  [366, 157]
# finished with  [366, 158]
# finished with  [366, 159]
# finished with  [366, 160]
# finished with  [366, 161]
# finished with  [366, 162]
# finished with  [366, 163]
# finished with  [366, 164]
# finished with  [366, 165]
# finished with  [366, 166]
# finished with  [366, 167]
# finished with  [366, 168]
# finished with  [366, 169]
# finished with  [366, 170]
# finished with  [366, 171]
# finished with  [366, 172]
# finished with  [366, 173]
# finished with  [366, 174]
# finished with  [366, 175]
# finished with  [366, 176]
# finished with  [366, 177]
# finished with  [366, 178]
# finished with  [366, 179]
# finished with  [367, 120]
# finished with  [367, 121]
# finished with  [367, 122]
# finished with  [367, 123]
# finished with  [367, 124]
# finished with  [367, 125]
# finished with  [367, 126]
# finished with  [367, 127]
# finished with  [367, 128]
# finished with  [367, 129]
# finished with  [367, 130]
# finished with  [367, 131]
# finished with  [367, 132]
# finished with  [367, 133]
# finished with  [367, 134]
# finished with  [367, 135]
# finished with  [367, 136]
# finished with  [367, 137]
# finished with  [367, 138]
# finished with  [367, 139]
# finished with  [367, 140]
# finished with  [367, 141]
# finished with  [367, 142]
# finished with  [367, 143]
# finished with  [367, 144]
# finished with  [367, 145]
# finished with  [367, 146]
# finished with  [367, 147]
# finished with  [367, 148]
# finished with  [367, 149]
# finished with  [367, 150]
# finished with  [367, 151]
# finished with  [367, 152]
# finished with  [367, 153]
# finished with  [367, 154]
# finished with  [367, 155]
# finished with  [367, 156]
# finished with  [367, 157]
# finished with  [367, 158]
# finished with  [367, 159]
# finished with  [367, 160]
# finished with  [367, 161]
# finished with  [367, 162]
# finished with  [367, 163]
# finished with  [367, 164]
# finished with  [367, 165]
# finished with  [367, 166]
# finished with  [367, 167]
# finished with  [367, 168]
# finished with  [367, 169]
# finished with  [367, 170]
# finished with  [367, 171]
# finished with  [367, 172]
# finished with  [367, 173]
# finished with  [367, 174]
# finished with  [367, 175]
# finished with  [367, 176]
# finished with  [367, 177]
# finished with  [367, 178]
# finished with  [367, 179]
# finished with  [368, 120]
# finished with  [368, 121]
# finished with  [368, 122]
# finished with  [368, 123]
# finished with  [368, 124]
# finished with  [368, 125]
# finished with  [368, 126]
# finished with  [368, 127]
# finished with  [368, 128]
# finished with  [368, 129]
# finished with  [368, 130]
# finished with  [368, 131]
# finished with  [368, 132]
# finished with  [368, 133]
# finished with  [368, 134]
# finished with  [368, 135]
# finished with  [368, 136]
# finished with  [368, 137]
# finished with  [368, 138]
# finished with  [368, 139]
# finished with  [368, 140]
# finished with  [368, 141]
# finished with  [368, 142]
# finished with  [368, 143]
# finished with  [368, 144]
# finished with  [368, 145]
# finished with  [368, 146]
# finished with  [368, 147]
# finished with  [368, 148]
# finished with  [368, 149]
# finished with  [368, 150]
# finished with  [368, 151]
# finished with  [368, 152]
# finished with  [368, 153]
# finished with  [368, 154]
# finished with  [368, 155]
# finished with  [368, 156]
# finished with  [368, 157]
# finished with  [368, 158]
# finished with  [368, 159]
# finished with  [368, 160]
# finished with  [368, 161]
# finished with  [368, 162]
# finished with  [368, 163]
# finished with  [368, 164]
# finished with  [368, 165]
# finished with  [368, 166]
# finished with  [368, 167]
# finished with  [368, 168]
# finished with  [368, 169]
# finished with  [368, 170]
# finished with  [368, 171]
# finished with  [368, 172]
# finished with  [368, 173]
# finished with  [368, 174]
# finished with  [368, 175]
# finished with  [368, 176]
# finished with  [368, 177]
# finished with  [368, 178]
# finished with  [368, 179]
# finished with  [369, 120]
# finished with  [369, 121]
# finished with  [369, 122]
# finished with  [369, 123]
# finished with  [369, 124]
# finished with  [369, 125]
# finished with  [369, 126]
# finished with  [369, 127]
# finished with  [369, 128]
# finished with  [369, 129]
# finished with  [369, 130]
# finished with  [369, 131]
# finished with  [369, 132]
# finished with  [369, 133]
# finished with  [369, 134]
# finished with  [369, 135]
# finished with  [369, 136]
# finished with  [369, 137]
# finished with  [369, 138]
# finished with  [369, 139]
# finished with  [369, 140]
# finished with  [369, 141]
# finished with  [369, 142]
# finished with  [369, 143]
# finished with  [369, 144]
# finished with  [369, 145]
# finished with  [369, 146]
# finished with  [369, 147]
# finished with  [369, 148]
# finished with  [369, 149]
# finished with  [369, 150]
# finished with  [369, 151]
# finished with  [369, 152]
# finished with  [369, 153]
# finished with  [369, 154]
# finished with  [369, 155]
# finished with  [369, 156]
# finished with  [369, 157]
# finished with  [369, 158]
# finished with  [369, 159]
# finished with  [369, 160]
# finished with  [369, 161]
# finished with  [369, 162]
# finished with  [369, 163]
# finished with  [369, 164]
# finished with  [369, 165]
# finished with  [369, 166]
# finished with  [369, 167]
# finished with  [369, 168]
# finished with  [369, 169]
# finished with  [378, 148]
# finished with  [378, 149]
# finished with  [378, 150]
# finished with  [378, 151]
# finished with  [378, 152]
# finished with  [378, 153]
# finished with  [378, 154]
# finished with  [378, 155]
# finished with  [378, 156]
# finished with  [378, 157]
# finished with  [378, 158]
# finished with  [378, 159]
# finished with  [378, 160]
# finished with  [378, 161]
# finished with  [378, 162]
# finished with  [378, 163]
# finished with  [378, 164]
# finished with  [378, 165]
# finished with  [378, 166]
# finished with  [378, 167]
# finished with  [378, 168]
# finished with  [378, 169]
# finished with  [378, 170]
# finished with  [378, 171]
# finished with  [378, 172]
# finished with  [378, 173]
# finished with  [378, 174]
# finished with  [378, 175]
# finished with  [378, 176]
# finished with  [378, 177]
# finished with  [378, 178]
# finished with  [378, 179]
# finished with  [379, 120]
# finished with  [379, 121]
# finished with  [379, 122]
# finished with  [379, 123]
# finished with  [379, 124]
# finished with  [379, 125]
# finished with  [379, 126]
# finished with  [379, 127]
# finished with  [379, 128]
# finished with  [379, 129]
# finished with  [379, 130]
# finished with  [379, 131]
# finished with  [379, 132]
# finished with  [379, 133]
# finished with  [379, 134]
# finished with  [379, 135]
# finished with  [379, 136]
# finished with  [379, 137]
# finished with  [379, 138]
# finished with  [379, 139]
# finished with  [379, 140]
# finished with  [379, 141]
# finished with  [379, 142]
# finished with  [379, 143]
# finished with  [379, 144]
# finished with  [379, 145]
# finished with  [379, 146]
# finished with  [379, 147]
# finished with  [379, 148]
# finished with  [379, 149]
# finished with  [379, 150]
# finished with  [379, 151]
# finished with  [379, 152]
# finished with  [379, 153]
# finished with  [379, 154]
# finished with  [379, 155]
# finished with  [379, 156]
# finished with  [379, 157]
# finished with  [379, 158]
# finished with  [379, 159]
# finished with  [379, 160]
# finished with  [379, 161]
# finished with  [379, 162]
# finished with  [379, 163]
# finished with  [379, 164]
# finished with  [379, 165]
# finished with  [379, 166]
# finished with  [379, 167]
# finished with  [379, 168]
# finished with  [379, 169]
# finished with  [379, 170]
# finished with  [379, 171]
# finished with  [379, 172]
# finished with  [379, 173]
# finished with  [379, 174]
# finished with  [379, 175]
# finished with  [379, 176]
# finished with  [379, 177]
# finished with  [379, 178]
# finished with  [379, 179]
# finished with  [380, 120]
# finished with  [380, 121]
# finished with  [380, 122]
# finished with  [380, 123]
# finished with  [380, 124]
# finished with  [380, 125]
# finished with  [380, 126]
# finished with  [380, 127]
# finished with  [380, 128]
# finished with  [380, 129]
# finished with  [380, 130]
# finished with  [380, 131]
# finished with  [380, 132]
# finished with  [380, 133]
# finished with  [380, 134]
# finished with  [380, 135]
# finished with  [380, 136]
# finished with  [380, 137]
# finished with  [380, 138]
# finished with  [380, 139]
# finished with  [380, 140]
# finished with  [380, 141]
# finished with  [380, 142]
# finished with  [380, 143]
# finished with  [380, 144]
# finished with  [380, 145]
# finished with  [380, 146]
# finished with  [380, 147]
# finished with  [380, 148]
# finished with  [380, 149]
# finished with  [380, 150]
# finished with  [380, 151]
# finished with  [380, 152]
# finished with  [380, 153]
# finished with  [380, 154]
# finished with  [380, 155]
# finished with  [380, 156]
# finished with  [380, 157]
# finished with  [380, 158]
# finished with  [380, 159]
# finished with  [380, 160]
# finished with  [380, 161]
# finished with  [380, 162]
# finished with  [380, 163]
# finished with  [380, 164]
# finished with  [380, 165]
# finished with  [380, 166]
# finished with  [380, 167]
# finished with  [380, 168]
# finished with  [380, 169]
# finished with  [380, 170]
# finished with  [380, 171]
# finished with  [380, 172]
# finished with  [380, 173]
# finished with  [380, 174]
# finished with  [380, 175]
# finished with  [380, 176]
# finished with  [380, 177]
# finished with  [380, 178]
# finished with  [380, 179]
# finished with  [381, 120]
# finished with  [381, 121]
# finished with  [381, 122]
# finished with  [381, 123]
# finished with  [381, 124]
# finished with  [381, 125]
# finished with  [381, 126]
# finished with  [381, 127]
# finished with  [381, 128]
# finished with  [381, 129]
# finished with  [381, 130]
# finished with  [381, 131]
# finished with  [381, 132]
# finished with  [381, 133]
# finished with  [381, 134]
# finished with  [381, 135]
# finished with  [381, 136]
# finished with  [381, 137]
# finished with  [381, 138]
# finished with  [381, 139]
# finished with  [381, 140]
# finished with  [381, 141]
# finished with  [381, 142]
# finished with  [381, 143]
# finished with  [381, 144]
# finished with  [381, 145]
# finished with  [381, 146]
# finished with  [381, 147]
# finished with  [381, 148]
# finished with  [381, 149]
# finished with  [381, 150]
# finished with  [381, 151]
# finished with  [381, 152]
# finished with  [381, 153]
# finished with  [381, 154]
# finished with  [381, 155]
# finished with  [381, 156]
# finished with  [381, 157]
# finished with  [381, 158]
# finished with  [381, 159]
# finished with  [381, 160]
# finished with  [381, 161]
# finished with  [381, 162]
# finished with  [381, 163]
# finished with  [381, 164]
# finished with  [381, 165]
# finished with  [381, 166]
# finished with  [381, 167]
# finished with  [381, 168]
# finished with  [381, 169]
# finished with  [381, 170]
# finished with  [381, 171]
# finished with  [381, 172]
# finished with  [381, 173]
# finished with  [381, 174]
# finished with  [381, 175]
# finished with  [381, 176]
# finished with  [381, 177]
# finished with  [381, 178]
# finished with  [381, 179]
# finished with  [382, 120]
# finished with  [382, 121]
# finished with  [382, 122]
# finished with  [382, 123]
# finished with  [382, 124]
# finished with  [382, 125]
# finished with  [382, 126]
# finished with  [382, 127]
# finished with  [382, 128]
# finished with  [382, 129]
# finished with  [382, 130]
# finished with  [382, 131]
# finished with  [382, 132]
# finished with  [382, 133]
# finished with  [382, 134]
# finished with  [382, 135]
# finished with  [382, 136]
# finished with  [382, 137]
# finished with  [382, 138]
# finished with  [382, 139]
# finished with  [382, 140]
# finished with  [382, 141]
# finished with  [382, 142]
# finished with  [382, 143]
# finished with  [382, 144]
# finished with  [382, 145]
# finished with  [382, 146]
# finished with  [382, 147]
# finished with  [382, 148]
# finished with  [382, 149]
# finished with  [382, 150]
# finished with  [382, 151]
# finished with  [382, 152]
# finished with  [382, 153]
# finished with  [382, 154]
# finished with  [382, 155]
# finished with  [382, 156]
# finished with  [382, 157]
# finished with  [382, 158]
# finished with  [382, 159]
# finished with  [382, 160]
# finished with  [382, 161]
# finished with  [382, 162]
# finished with  [382, 163]
# finished with  [382, 164]
# finished with  [382, 165]
# finished with  [382, 166]
# finished with  [382, 167]
# finished with  [382, 168]
# finished with  [382, 169]
# finished with  [382, 170]
# finished with  [382, 171]
# finished with  [382, 172]
# finished with  [382, 173]
# finished with  [382, 174]
# finished with  [382, 175]
# finished with  [382, 176]
# finished with  [382, 177]
# finished with  [382, 178]
# finished with  [382, 179]
# finished with  [383, 120]
# finished with  [383, 121]
# finished with  [383, 122]
# finished with  [383, 123]
# finished with  [383, 124]
# finished with  [383, 125]
# finished with  [383, 126]
# finished with  [383, 127]
# finished with  [383, 128]
# finished with  [383, 129]
# finished with  [383, 130]
# finished with  [383, 131]
# finished with  [383, 132]
# finished with  [383, 133]
# finished with  [383, 134]
# finished with  [383, 135]
# finished with  [383, 136]
# finished with  [383, 137]
# finished with  [383, 138]
# finished with  [383, 139]
# finished with  [383, 140]
# finished with  [383, 141]
# finished with  [383, 142]
# finished with  [383, 143]
# finished with  [383, 144]
# finished with  [383, 145]
# finished with  [383, 146]
# finished with  [383, 147]
# finished with  [383, 148]
# finished with  [383, 149]
# finished with  [383, 150]
# finished with  [383, 151]
# finished with  [383, 152]
# finished with  [383, 153]
# finished with  [383, 154]
# finished with  [383, 155]
# finished with  [383, 156]
# finished with  [383, 157]
# finished with  [383, 158]
# finished with  [383, 159]
# finished with  [383, 160]
# finished with  [383, 161]
# finished with  [383, 162]
# finished with  [383, 163]
# finished with  [383, 164]
# finished with  [383, 165]
# finished with  [383, 166]
# finished with  [383, 167]
# finished with  [383, 168]
# finished with  [383, 169]
# finished with  [383, 170]
# finished with  [383, 171]
# finished with  [383, 172]
# finished with  [383, 173]
# finished with  [383, 174]
# finished with  [383, 175]
# finished with  [383, 176]
# finished with  [383, 177]
# finished with  [383, 178]
# finished with  [383, 179]
# finished with  [384, 120]
# finished with  [384, 121]
# finished with  [384, 122]
# finished with  [384, 123]
# finished with  [384, 124]
# finished with  [384, 125]
# finished with  [384, 126]
# finished with  [384, 127]
# finished with  [384, 128]
# finished with  [384, 129]
# finished with  [384, 130]
# finished with  [384, 131]
# finished with  [384, 132]
# finished with  [384, 133]
# finished with  [384, 134]
# finished with  [384, 135]
# finished with  [384, 136]
# finished with  [384, 137]
# finished with  [384, 138]
# finished with  [384, 139]
# finished with  [384, 140]
# finished with  [384, 141]
# finished with  [384, 142]
# finished with  [384, 143]
# finished with  [384, 144]
# finished with  [384, 145]
# finished with  [384, 146]
# finished with  [384, 147]
# finished with  [384, 148]
# finished with  [384, 149]
# finished with  [384, 150]
# finished with  [384, 151]
# finished with  [384, 152]
# finished with  [384, 153]
# finished with  [384, 154]
# finished with  [384, 155]
# finished with  [384, 156]
# finished with  [384, 157]
# finished with  [384, 158]
# finished with  [384, 159]
# finished with  [384, 160]
# finished with  [384, 161]
# finished with  [384, 162]
# finished with  [384, 163]
# finished with  [384, 164]
# finished with  [384, 165]
# finished with  [384, 166]
# finished with  [384, 167]
# finished with  [384, 168]
# finished with  [384, 169]
# finished with  [384, 170]
# finished with  [384, 171]
# finished with  [384, 172]
# finished with  [384, 173]
# finished with  [384, 174]
# finished with  [384, 175]
# finished with  [384, 176]
# finished with  [389, 135]
# finished with  [389, 136]
# finished with  [389, 137]
# finished with  [389, 138]
# finished with  [389, 139]
# finished with  [389, 140]
# finished with  [389, 141]
# finished with  [389, 142]
# finished with  [389, 143]
# finished with  [389, 144]
# finished with  [389, 145]
# finished with  [389, 146]
# finished with  [389, 147]
# finished with  [389, 148]
# finished with  [389, 149]
# finished with  [389, 150]
# finished with  [389, 151]
# finished with  [389, 152]
# finished with  [389, 153]
# finished with  [389, 154]
# finished with  [389, 155]
# finished with  [389, 156]
# finished with  [389, 157]
# finished with  [389, 158]
# finished with  [389, 159]
# finished with  [389, 160]
# finished with  [389, 161]
# finished with  [389, 162]
# finished with  [389, 163]
# finished with  [389, 164]
# finished with  [389, 165]
# finished with  [389, 166]
# finished with  [389, 167]
# finished with  [389, 168]
# finished with  [389, 169]
# finished with  [389, 170]
# finished with  [389, 171]
# finished with  [389, 172]
# finished with  [389, 173]
# finished with  [389, 174]
# finished with  [389, 175]
# finished with  [389, 176]
# finished with  [389, 177]
# finished with  [389, 178]
# finished with  [389, 179]
# finished with  [390, 120]
# finished with  [390, 121]
# finished with  [390, 122]
# finished with  [390, 123]
# finished with  [390, 124]
# finished with  [390, 125]
# finished with  [390, 126]
# finished with  [390, 127]
# finished with  [390, 128]
# finished with  [390, 129]
# finished with  [390, 130]
# finished with  [390, 131]
# finished with  [390, 132]
# finished with  [390, 133]
# finished with  [390, 134]
# finished with  [390, 135]
# finished with  [390, 136]
# finished with  [390, 137]
# finished with  [390, 138]
# finished with  [390, 139]
# finished with  [390, 140]
# finished with  [390, 141]
# finished with  [390, 142]
# finished with  [390, 143]
# finished with  [390, 144]
# finished with  [390, 145]
# finished with  [390, 146]
# finished with  [390, 147]
# finished with  [390, 148]
# finished with  [390, 149]
# finished with  [390, 150]
# finished with  [390, 151]
# finished with  [390, 152]
# finished with  [390, 153]
# finished with  [390, 154]
# finished with  [390, 155]
# finished with  [390, 156]
# finished with  [390, 157]
# finished with  [390, 158]
# finished with  [390, 159]
# finished with  [390, 160]
# finished with  [390, 161]
# finished with  [390, 162]
# finished with  [390, 163]
# finished with  [390, 164]
# finished with  [390, 165]
# ...
# finished with  [429, 165]
# finished with  [429, 166]
# finished with  [429, 167]
# finished with  [429, 168]
# finished with  [429, 169]
# finished with  [429, 170]
# finished with  [429, 171]
# finished with  [429, 172]
# finished with  [429, 173]
# finished with  [429, 174]
# finished with  [429, 175]
# finished with  [429, 176]
# finished with  [429, 177]
# finished with  [429, 178]
# finished with  [429, 179]
# finished with  [430, 120]
# finished with  [430, 121]
# finished with  [430, 122]
# finished with  [430, 123]
# finished with  [430, 124]
# finished with  [430, 125]
# finished with  [430, 126]
# finished with  [430, 127]
# finished with  [430, 128]
# finished with  [430, 129]
# finished with  [430, 130]
# finished with  [430, 131]
# finished with  [430, 132]
# finished with  [430, 133]
# finished with  [430, 134]
# finished with  [430, 135]
# finished with  [430, 136]
# finished with  [430, 137]
# finished with  [430, 138]
# finished with  [430, 139]
# finished with  [430, 140]
# finished with  [430, 141]
# finished with  [430, 142]
# finished with  [430, 143]
# finished with  [430, 144]
# finished with  [430, 145]
# finished with  [430, 146]
# finished with  [430, 147]
# finished with  [430, 148]
# finished with  [430, 149]
# finished with  [430, 150]
# finished with  [430, 151]
# finished with  [430, 152]
# finished with  [430, 153]
# finished with  [430, 154]
# finished with  [430, 155]
# finished with  [430, 156]
# finished with  [430, 157]
# finished with  [430, 158]
# finished with  [430, 159]
# finished with  [430, 160]
# finished with  [430, 161]
# finished with  [430, 162]
# finished with  [430, 163]
# finished with  [430, 164]
# finished with  [430, 165]
# finished with  [430, 166]
# finished with  [430, 167]
# finished with  [430, 168]
# finished with  [430, 169]
# finished with  [430, 170]
# finished with  [430, 171]
# finished with  [430, 172]
# finished with  [430, 173]
# finished with  [430, 174]
# finished with  [430, 175]
# finished with  [430, 176]
# finished with  [430, 177]
# finished with  [430, 178]
# finished with  [430, 179]
# finished with  [431, 120]
# finished with  [431, 121]
# finished with  [431, 122]
# finished with  [431, 123]
# finished with  [431, 124]
# finished with  [431, 125]
# finished with  [431, 126]
# finished with  [431, 127]
# finished with  [431, 128]
# finished with  [431, 129]
# finished with  [431, 130]
# finished with  [431, 131]
# finished with  [431, 132]
# finished with  [431, 133]
# finished with  [431, 134]
# finished with  [431, 135]
# finished with  [431, 136]
# finished with  [431, 137]
# finished with  [431, 138]
# finished with  [431, 139]
# finished with  [431, 140]
# finished with  [431, 141]
# finished with  [431, 142]
# finished with  [431, 143]
# finished with  [431, 144]
# finished with  [431, 145]
# finished with  [431, 146]
# finished with  [431, 147]
# finished with  [431, 148]
# finished with  [431, 149]
# finished with  [431, 150]
# finished with  [431, 151]
# finished with  [431, 152]
# finished with  [431, 153]
# finished with  [431, 154]
# finished with  [431, 155]
# finished with  [431, 156]
# finished with  [431, 157]
# finished with  [431, 158]
# finished with  [431, 159]
# finished with  [431, 160]
# finished with  [431, 161]
# finished with  [431, 162]
# finished with  [431, 163]
# finished with  [431, 164]
# finished with  [431, 165]
# finished with  [431, 166]
# finished with  [431, 167]
# finished with  [431, 168]
# finished with  [431, 169]
# finished with  [431, 170]
# finished with  [431, 171]
# finished with  [431, 172]
# finished with  [431, 173]
# finished with  [431, 174]
# finished with  [431, 175]
# finished with  [431, 176]
# finished with  [431, 177]
# finished with  [431, 178]
# finished with  [431, 179]
# finished with  [432, 120]
# finished with  [432, 121]
# finished with  [432, 122]
# finished with  [432, 123]
# finished with  [432, 124]
# finished with  [432, 125]
# finished with  [432, 126]
# finished with  [432, 127]
# finished with  [432, 128]
# finished with  [432, 129]
# finished with  [432, 130]
# finished with  [432, 131]
# finished with  [432, 132]
# finished with  [432, 133]
# finished with  [432, 134]
# finished with  [432, 135]
# finished with  [432, 136]
# finished with  [432, 137]
# finished with  [432, 138]
# finished with  [432, 139]
# finished with  [432, 140]
# finished with  [432, 141]
# finished with  [432, 142]
# finished with  [432, 143]
# finished with  [432, 144]
# finished with  [432, 145]
# finished with  [432, 146]
# finished with  [432, 147]
# finished with  [432, 148]
# finished with  [432, 149]
# finished with  [432, 150]
# finished with  [432, 151]
# finished with  [432, 152]
# finished with  [432, 153]
# finished with  [432, 154]
# finished with  [432, 155]
# finished with  [432, 156]
# finished with  [432, 157]
# finished with  [432, 158]
# finished with  [432, 159]
# finished with  [432, 160]
# finished with  [432, 161]
# finished with  [432, 162]
# finished with  [432, 163]
# finished with  [432, 164]
# finished with  [432, 165]
# finished with  [432, 166]
# finished with  [432, 167]
# finished with  [432, 168]
# finished with  [432, 169]
# finished with  [432, 170]
# finished with  [432, 171]
# finished with  [432, 172]
# finished with  [432, 173]
# finished with  [432, 174]
# finished with  [432, 175]
# finished with  [432, 176]
# finished with  [432, 177]
# finished with  [432, 178]
# finished with  [432, 179]
# finished with  [433, 120]
# finished with  [433, 121]
# finished with  [433, 122]
# finished with  [433, 123]
# finished with  [433, 124]
# finished with  [433, 125]
# finished with  [433, 126]
# finished with  [433, 127]
# finished with  [433, 128]
# finished with  [433, 129]
# finished with  [433, 130]
# finished with  [433, 131]
# finished with  [433, 132]
# finished with  [433, 133]
# finished with  [433, 134]
# finished with  [433, 135]
# finished with  [433, 136]
# finished with  [433, 137]
# finished with  [433, 138]
# finished with  [433, 139]
# finished with  [433, 140]
# finished with  [433, 141]
# finished with  [433, 142]
# finished with  [433, 143]
# finished with  [433, 144]
# finished with  [433, 145]
# finished with  [433, 146]
# finished with  [433, 147]
# finished with  [433, 148]
# finished with  [433, 149]
# finished with  [433, 150]
# finished with  [433, 151]
# finished with  [433, 152]
# finished with  [433, 153]
# finished with  [433, 154]
# finished with  [433, 155]
# finished with  [433, 156]
# finished with  [433, 157]
# finished with  [433, 158]
# finished with  [433, 159]
# finished with  [433, 160]
# finished with  [433, 161]
# finished with  [433, 162]
# finished with  [433, 163]
# finished with  [433, 164]
# finished with  [433, 165]
# finished with  [433, 166]
# finished with  [433, 167]
# finished with  [433, 168]
# finished with  [433, 169]
# finished with  [433, 170]
# finished with  [433, 171]
# finished with  [433, 172]
# finished with  [433, 173]
# finished with  [433, 174]
# finished with  [433, 175]
# finished with  [433, 176]
# finished with  [433, 177]
# finished with  [433, 178]
# finished with  [433, 179]
# finished with  [434, 120]
# finished with  [434, 121]
# finished with  [434, 122]
# finished with  [434, 123]
# finished with  [434, 124]
# finished with  [434, 125]
# finished with  [434, 126]
# finished with  [434, 127]
# finished with  [434, 128]
# finished with  [434, 129]
# finished with  [434, 130]
# finished with  [434, 131]
# finished with  [434, 132]
# finished with  [434, 133]
# finished with  [434, 134]
# finished with  [434, 135]
# finished with  [434, 136]
# finished with  [434, 137]
# finished with  [434, 138]
# finished with  [434, 139]
# finished with  [434, 140]
# finished with  [434, 141]
# finished with  [434, 142]
# finished with  [434, 143]
# finished with  [434, 144]
# finished with  [434, 145]
# finished with  [434, 146]
# finished with  [434, 147]
# finished with  [434, 148]
# finished with  [434, 149]
# finished with  [434, 150]
# finished with  [434, 151]
# finished with  [434, 152]
# finished with  [434, 153]
# finished with  [434, 154]
# finished with  [434, 155]
# finished with  [434, 156]
# finished with  [434, 157]
# finished with  [434, 158]
# finished with  [434, 159]
# finished with  [434, 160]
# finished with  [434, 161]
# finished with  [434, 162]
# finished with  [434, 163]
# finished with  [434, 164]
# finished with  [434, 165]
# finished with  [434, 166]
# finished with  [434, 167]
# finished with  [434, 168]
# finished with  [434, 169]
# finished with  [434, 170]
# finished with  [434, 171]
# finished with  [434, 172]
# finished with  [434, 173]
# finished with  [434, 174]
# finished with  [434, 175]
# finished with  [434, 176]
# finished with  [434, 177]
# finished with  [434, 178]
# finished with  [434, 179]
# finished with  [435, 120]
# finished with  [435, 121]
# finished with  [435, 122]
# finished with  [435, 123]
# finished with  [435, 124]
# finished with  [435, 125]
# finished with  [435, 126]
# finished with  [435, 127]
# finished with  [435, 128]
# finished with  [435, 129]
# finished with  [435, 130]
# finished with  [435, 131]
# finished with  [435, 132]
# finished with  [435, 133]
# finished with  [435, 134]
# finished with  [435, 135]
# finished with  [435, 136]
# finished with  [435, 137]
# finished with  [435, 138]
# finished with  [435, 139]
# finished with  [435, 140]
# finished with  [435, 141]
# finished with  [435, 142]
# finished with  [435, 143]
# finished with  [435, 144]
# finished with  [435, 145]
# finished with  [435, 146]
# finished with  [435, 147]
# finished with  [435, 148]
# finished with  [435, 149]
# finished with  [435, 150]
# finished with  [435, 151]
# finished with  [435, 152]
# finished with  [435, 153]
# finished with  [435, 154]
# finished with  [435, 155]
# finished with  [435, 156]
# finished with  [435, 157]
# finished with  [435, 158]
# finished with  [435, 159]
# finished with  [435, 160]
# finished with  [435, 161]
# finished with  [435, 162]
# finished with  [435, 163]
# finished with  [435, 164]
# finished with  [435, 165]
# finished with  [435, 166]
# finished with  [435, 167]
# finished with  [435, 168]
# finished with  [435, 169]
# finished with  [435, 170]
# finished with  [435, 171]
# finished with  [435, 172]
# finished with  [435, 173]
# finished with  [435, 174]
# finished with  [435, 175]
# finished with  [435, 176]
# finished with  [435, 177]
# finished with  [435, 178]
# finished with  [435, 179]
# finished with  [436, 120]
# finished with  [436, 121]
# finished with  [436, 122]
# finished with  [436, 123]
# finished with  [436, 124]
# finished with  [436, 125]
# finished with  [436, 126]
# finished with  [436, 127]
# finished with  [436, 128]
# finished with  [436, 129]
# finished with  [436, 130]
# finished with  [436, 131]
# finished with  [436, 132]
# finished with  [436, 133]
# finished with  [436, 134]
# finished with  [436, 135]
# finished with  [436, 136]
# finished with  [436, 137]
# finished with  [436, 138]
# finished with  [436, 139]
# finished with  [436, 140]
# finished with  [436, 141]
# finished with  [436, 142]
# finished with  [436, 143]
# finished with  [436, 144]
# finished with  [436, 145]
# finished with  [436, 146]
# finished with  [436, 147]
# finished with  [436, 148]
# finished with  [436, 149]
# finished with  [436, 150]
# finished with  [436, 151]
# finished with  [436, 152]
# finished with  [436, 153]
# finished with  [436, 154]
# finished with  [436, 155]
# finished with  [436, 156]
# finished with  [436, 157]
# finished with  [436, 158]
# finished with  [436, 159]
# finished with  [436, 160]
# finished with  [436, 161]
# finished with  [436, 162]
# finished with  [436, 163]
# finished with  [436, 164]
# finished with  [436, 165]
# finished with  [436, 166]
# finished with  [436, 167]
# finished with  [436, 168]
# finished with  [436, 169]
# finished with  [436, 170]
# finished with  [436, 171]
# finished with  [436, 172]
# finished with  [436, 173]
# finished with  [436, 174]
# finished with  [436, 175]
# finished with  [436, 176]
# finished with  [436, 177]
# finished with  [436, 178]
# finished with  [436, 179]
# finished with  [437, 120]
# finished with  [437, 121]
# finished with  [437, 122]
# finished with  [437, 123]
# finished with  [437, 124]
# finished with  [437, 125]
# finished with  [437, 126]
# finished with  [437, 127]
# finished with  [437, 128]
# finished with  [437, 129]
# finished with  [437, 130]
# finished with  [437, 131]
# finished with  [437, 132]
# finished with  [437, 133]
# finished with  [437, 134]
# finished with  [437, 135]
# finished with  [437, 136]
# finished with  [437, 137]
# finished with  [437, 138]
# finished with  [437, 139]
# finished with  [437, 140]
# finished with  [437, 141]
# finished with  [437, 142]
# finished with  [437, 143]
# finished with  [437, 144]
# finished with  [437, 145]
# finished with  [437, 146]
# finished with  [437, 147]
# finished with  [437, 148]
# finished with  [437, 149]
# finished with  [437, 150]
# finished with  [437, 151]
# finished with  [437, 152]
# finished with  [437, 153]
# finished with  [437, 154]
# finished with  [437, 155]
# finished with  [437, 156]
# finished with  [437, 157]
# finished with  [437, 158]
# finished with  [437, 159]
# finished with  [437, 160]
# finished with  [437, 161]
# finished with  [437, 162]
# finished with  [437, 163]
# finished with  [437, 164]
# finished with  [437, 165]
# finished with  [437, 166]
# finished with  [437, 167]
# finished with  [437, 168]
# finished with  [437, 169]
# finished with  [437, 170]
# finished with  [437, 171]
# finished with  [437, 172]
# finished with  [437, 173]
# finished with  [437, 174]
# finished with  [437, 175]
# finished with  [437, 176]
# finished with  [437, 177]
# finished with  [437, 178]
# finished with  [437, 179]
# finished with  [438, 120]
# finished with  [438, 121]
# finished with  [438, 122]
# finished with  [438, 123]
# finished with  [438, 124]
# finished with  [438, 125]
# finished with  [438, 126]
# finished with  [438, 127]
# finished with  [438, 128]
# finished with  [438, 129]
# finished with  [438, 130]
# finished with  [438, 131]
# finished with  [438, 132]
# finished with  [438, 133]
# finished with  [438, 134]
# finished with  [438, 135]
# finished with  [438, 136]
# finished with  [438, 137]
# finished with  [438, 138]
# finished with  [438, 139]
# finished with  [438, 140]
# finished with  [438, 141]
# finished with  [438, 142]
# finished with  [438, 143]
# finished with  [438, 144]
# finished with  [438, 145]
# finished with  [438, 146]
# finished with  [438, 147]
# finished with  [438, 148]
# finished with  [438, 149]
# finished with  [438, 150]
# finished with  [438, 151]
# finished with  [438, 152]
# finished with  [438, 153]
# finished with  [438, 154]
# finished with  [438, 155]
# finished with  [438, 156]
# finished with  [438, 157]
# finished with  [438, 158]
# finished with  [438, 159]
# finished with  [438, 160]
# finished with  [438, 161]
# finished with  [438, 162]
# finished with  [438, 163]
# finished with  [438, 164]
# finished with  [438, 165]
# finished with  [438, 166]
# finished with  [438, 167]
# finished with  [438, 168]
# finished with  [438, 169]
# finished with  [438, 170]
# finished with  [438, 171]
# finished with  [438, 172]
# finished with  [438, 173]
# finished with  [438, 174]
# finished with  [438, 175]
# finished with  [438, 176]
# finished with  [438, 177]
# finished with  [438, 178]
# finished with  [438, 179]
# finished with  [439, 120]
# finished with  [439, 121]
# finished with  [439, 122]
# finished with  [439, 123]
# finished with  [439, 124]
# finished with  [439, 125]
# finished with  [439, 126]
# finished with  [439, 127]
# finished with  [439, 128]
# finished with  [439, 129]
# finished with  [439, 130]
# finished with  [439, 131]
# finished with  [439, 132]
# finished with  [439, 133]
# finished with  [439, 134]
# finished with  [439, 135]
# finished with  [439, 136]
# finished with  [439, 137]
# finished with  [439, 138]
# finished with  [439, 139]
# finished with  [439, 140]
# finished with  [439, 141]
# finished with  [439, 142]
# finished with  [439, 143]
# finished with  [439, 144]
# finished with  [439, 145]
# finished with  [439, 146]
# finished with  [439, 147]
# finished with  [439, 148]
# finished with  [439, 149]
# finished with  [439, 150]
# finished with  [439, 151]
# finished with  [439, 152]
# finished with  [439, 153]
# finished with  [439, 154]
# finished with  [439, 155]
# finished with  [439, 156]
# finished with  [439, 157]
# finished with  [439, 158]
# finished with  [439, 159]
# finished with  [439, 160]
# finished with  [439, 161]
# finished with  [439, 162]
# finished with  [439, 163]
# finished with  [439, 164]
# finished with  [439, 165]
# finished with  [439, 166]
# finished with  [439, 167]
# finished with  [439, 168]
# finished with  [439, 169]
# finished with  [439, 170]
# finished with  [439, 171]
# finished with  [439, 172]
# finished with  [439, 173]
# finished with  [439, 174]
# finished with  [439, 175]
# finished with  [439, 176]
# finished with  [439, 177]
# finished with  [439, 178]
# finished with  [439, 179]

# %% [markdown]
# Now that we have the non-divergent wind, let's create another plot!

# %%
# Create a figure instance.
fig = plt.figure(figsize=(12,9), dpi=300.)

# Create a set of axes for the figure and set
# its map projection to that of the input data.
ax = plt.axes(projection=crs.PlateCarree())

# Add country borders and coastlines.
countries = NaturalEarthFeature(category="cultural", scale="50m",
                                      facecolor="none",
                                      name="admin_0_countries")
ax.add_feature(countries, linewidth=.5, edgecolor="black")
ax.coastlines('50m', linewidth=0.8)

# Compute the wind speed for the non-divergent component of the 850 hPa wind.
nd_spd = np.sqrt(upsi**2 + vpsi**2)

# Plot this wind speed using xarray's plot functionality.
plot = nd_spd.plot(levels=np.arange(0., 13., 1.), cmap=get_cmap('YlGnBu'), transform=crs.PlateCarree(), cbar_kwargs={'label':'non-divergent wind ($m s^{-1}$)', 'shrink': 0.98})

# Set the map's extent to match that over which we computed the non-divergent wind.
ax.set_extent([-180.,-140.,0.,30.],crs=crs.PlateCarree())

# Add latitude/longitude gridlines.
gridlines = ax.gridlines(color="grey", linestyle="dotted", draw_labels=True)
gridlines.xlabels_top = False
gridlines.ylabels_right = False
gridlines.xlocator = mticker.FixedLocator(np.arange(-180.,139.,5.))
gridlines.ylocator = mticker.FixedLocator(np.arange(0.,31.,5.))
gridlines.xlabel_style = {'size':12, 'color':'black'}
gridlines.ylabel_style = {'size':12, 'color':'black'}
gridlines.xformatter = LONGITUDE_FORMATTER
gridlines.yformatter = LATITUDE_FORMATTER

# Add a plot title, then show the image.
plt.title("GFS 0-h 850 hPa non-divergent wind speed ($m s^{-1}$) due to Dora at 1200 UTC 9 August 2023")
plt.show()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
